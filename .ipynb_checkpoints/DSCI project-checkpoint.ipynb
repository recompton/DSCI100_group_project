# %%
library(tidyverse)
library(repr)
library(tidymodels)
source("tests.R")
source('cleanup.R')
set.seed(1000)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.5     ✔ rsample      1.2.0
# ✔ dials        1.2.0     ✔ tune         1.1.2
# ✔ infer        1.0.5     ✔ workflows    1.1.3
# ✔ modeldata    1.2.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.1.1     ✔ yardstick    1.2.0
# ✔ recipes      1.0.8
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Learn how to get started at https://www.tidymodels.org/start/
#
# Warning message in file(filename, "r", encoding = encoding):
# “cannot open file 'tests.R': No such file or directory”
# Error in file(filename, "r", encoding = encoding): cannot open the connection
# Traceback:
#
# 1. source("tests.R")
# 2. file(filename, "r", encoding = encoding)

# %%
air_quality <- read_csv("data/AirQualityDSCI.csv")
head(air_quality)
# Out:
# New names:
# • `` -> `...16`
# • `` -> `...17`
# Rows: 9471 Columns: 17
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (13): CO, PT08_S1, NMHC, C6H6(GT), PT08_S2, NOx(GT), PT08_S3, NO2(GT), ...
# lgl   (2): ...16, ...17
# date  (1): Date
# time  (1): Time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Date       Time     CO  PT08_S1 NMHC C6H6(GT) PT08_S2 NOx(GT) PT08_S3 NO2(GT)
# 1 2004-03-10 18:00:00 2.6 1360    150  11.9     1046    166     1056    113
# 2 2004-03-10 19:00:00 2.0 1292    112   9.4      955    103     1174     92
# 3 2004-03-10 20:00:00 2.2 1402     88   9.0      939    131     1140    114
# 4 2004-03-10 21:00:00 2.2 1376     80   9.2      948    172     1092    122
# 5 2004-03-10 22:00:00 1.6 1272     51   6.5      836    131     1205    116
# 6 2004-03-10 23:00:00 1.2 1197     38   4.7      750     89     1337     96
#   PT08_S4 PT08_S5 T    RH   AH     ...16 ...17
# 1 1692    1268    13.6 48.9 0.7578 NA    NA
# 2 1559     972    13.3 47.7 0.7255 NA    NA
# 3 1555    1074    11.9 54.0 0.7502 NA    NA
# 4 1584    1203    11.0 60.0 0.7867 NA    NA
# 5 1490    1110    11.2 59.6 0.7888 NA    NA
# 6 1393     949    11.2 59.2 0.7848 NA    NA

# %%
air_quality_1 <- mutate(air_quality, date = mdy(Date))
head(air_quality_1)
# Out:
# Warning message:
# “There was 1 warning in `mutate()`.
# ℹ In argument: `date = mdy(Date)`.
# Caused by warning:
# ! All formats failed to parse. No formats found.”
#   Date       Time     CO  PT08_S1 NMHC C6H6(GT) PT08_S2 NOx(GT) PT08_S3 NO2(GT)
# 1 2004-03-10 18:00:00 2.6 1360    150  11.9     1046    166     1056    113
# 2 2004-03-10 19:00:00 2.0 1292    112   9.4      955    103     1174     92
# 3 2004-03-10 20:00:00 2.2 1402     88   9.0      939    131     1140    114
# 4 2004-03-10 21:00:00 2.2 1376     80   9.2      948    172     1092    122
# 5 2004-03-10 22:00:00 1.6 1272     51   6.5      836    131     1205    116
# 6 2004-03-10 23:00:00 1.2 1197     38   4.7      750     89     1337     96
#   PT08_S4 PT08_S5 T    RH   AH     ...16 ...17 date
# 1 1692    1268    13.6 48.9 0.7578 NA    NA    <NA>
# 2 1559     972    13.3 47.7 0.7255 NA    NA    <NA>
# 3 1555    1074    11.9 54.0 0.7502 NA    NA    <NA>
# 4 1584    1203    11.0 60.0 0.7867 NA    NA    <NA>
# 5 1490    1110    11.2 59.6 0.7888 NA    NA    <NA>
# 6 1393     949    11.2 59.2 0.7848 NA    NA    <NA>

# %%
air_quality_2 <- air_quality_1 |>
mutate(year = year(Date),
month = month(Date),
day = day(Date))

head(air_quality_2)
# Out:
#   Date       Time     CO  PT08_S1 NMHC C6H6(GT) PT08_S2 NOx(GT) PT08_S3 NO2(GT)
# 1 2004-03-10 18:00:00 2.6 1360    150  11.9     1046    166     1056    113
# 2 2004-03-10 19:00:00 2.0 1292    112   9.4      955    103     1174     92
# 3 2004-03-10 20:00:00 2.2 1402     88   9.0      939    131     1140    114
# 4 2004-03-10 21:00:00 2.2 1376     80   9.2      948    172     1092    122
# 5 2004-03-10 22:00:00 1.6 1272     51   6.5      836    131     1205    116
# 6 2004-03-10 23:00:00 1.2 1197     38   4.7      750     89     1337     96
#   ⋯ PT08_S5 T    RH   AH     ...16 ...17 date year month day
# 1 ⋯ 1268    13.6 48.9 0.7578 NA    NA    <NA> 2004 3     10
# 2 ⋯  972    13.3 47.7 0.7255 NA    NA    <NA> 2004 3     10
# 3 ⋯ 1074    11.9 54.0 0.7502 NA    NA    <NA> 2004 3     10
# 4 ⋯ 1203    11.0 60.0 0.7867 NA    NA    <NA> 2004 3     10
# 5 ⋯ 1110    11.2 59.6 0.7888 NA    NA    <NA> 2004 3     10
# 6 ⋯  949    11.2 59.2 0.7848 NA    NA    <NA> 2004 3     10

# %%
sliced_air_quality <- air_quality_2 |>
slice(1:9357) 


head(sliced_air_quality)
# Out:
#   Date       Time     CO  PT08_S1 NMHC C6H6(GT) PT08_S2 NOx(GT) PT08_S3 NO2(GT)
# 1 2004-03-10 18:00:00 2.6 1360    150  11.9     1046    166     1056    113
# 2 2004-03-10 19:00:00 2.0 1292    112   9.4      955    103     1174     92
# 3 2004-03-10 20:00:00 2.2 1402     88   9.0      939    131     1140    114
# 4 2004-03-10 21:00:00 2.2 1376     80   9.2      948    172     1092    122
# 5 2004-03-10 22:00:00 1.6 1272     51   6.5      836    131     1205    116
# 6 2004-03-10 23:00:00 1.2 1197     38   4.7      750     89     1337     96
#   ⋯ PT08_S5 T    RH   AH     ...16 ...17 date year month day
# 1 ⋯ 1268    13.6 48.9 0.7578 NA    NA    <NA> 2004 3     10
# 2 ⋯  972    13.3 47.7 0.7255 NA    NA    <NA> 2004 3     10
# 3 ⋯ 1074    11.9 54.0 0.7502 NA    NA    <NA> 2004 3     10
# 4 ⋯ 1203    11.0 60.0 0.7867 NA    NA    <NA> 2004 3     10
# 5 ⋯ 1110    11.2 59.6 0.7888 NA    NA    <NA> 2004 3     10
# 6 ⋯  949    11.2 59.2 0.7848 NA    NA    <NA> 2004 3     10

# %%
avg_air_quality <- sliced_air_quality |>
filter(PT08_S4 != -200)|>
filter(T != -200) |>
filter(RH != -200) |>
filter(AH != -200) |>
group_by(month, day) |>
summarize(
    daily_avg_PT08_S4 = mean(PT08_S4, na.rm = TRUE),
    daily_avg_T = mean(T, na.rm = TRUE),
    daily_avg_RH = mean(RH, na.rm = TRUE),
    daily_avg_AH = mean(AH, na.rm = TRUE))


avg_air_quality_split <- initial_split(avg_air_quality, prop = 0.75, strata = daily_avg_PT08_S4)
avg_air_quality_train <- training(avg_air_quality_split)
avg_air_quality_test <- testing(avg_air_quality_split)

avg_air_quality_train
avg_air_quality_test
# Out:
# `summarise()` has grouped output by 'month'. You can override using the
# `.groups` argument.
#     month day daily_avg_PT08_S4 daily_avg_T daily_avg_RH daily_avg_AH
# 1   1      1  1032.6250          6.870833   50.79583     0.4989708
# 2   1      2  1063.1429          6.580952   59.28095     0.5709476
# 3   1      6  1226.5417         13.445833   61.07083     0.9321417
# 4   1      9  1257.7500         14.437500   58.99583     0.9614458
# 5   1     15  1210.5000          6.429167   70.20417     0.6710333
# 6   1     17  1163.3333          6.666667   46.91667     0.4469125
# 7   1     19  1072.4583          7.816667   64.99583     0.6895000
# 8   1     20  1136.7500         10.075000   44.24583     0.5263417
# 9   1     22  1283.5000          9.941667   55.85417     0.6523542
# 10  1     23   998.7500          5.816667   53.88333     0.5014125
# 11  1     24   977.4583          7.675000   47.88333     0.4938125
# 12  1     25   869.3750          4.512500   50.97083     0.4323125
# 13  1     26   873.0417          4.208333   49.48333     0.4119333
# 14  1     28   885.0000          3.982353   48.45882     0.3979588
# 15  1     29   807.0455          2.618182   49.34545     0.3679773
# 16  1     30   763.7917          4.850000   37.83750     0.3249958
# 17  1     31  1001.5000          7.283333   31.80833     0.3119542
# 18  2      1  1184.4167          6.625000   51.74167     0.5041875
# 19  2      2  1132.2083          7.612500   43.93750     0.4263500
# 20  2      3  1212.2083          7.254167   50.96250     0.5132417
# 21  2      4  1081.7500          7.466667   50.17917     0.4960292
# 22  2      6   821.7500          5.304167   39.60000     0.3437333
# 23  2     15   881.1250          8.962500   30.21250     0.3368375
# 24  2     16  1052.3333          6.491667   42.62500     0.4093333
# 25  2     18  1012.5000          8.504167   42.18333     0.4623958
# 26  2     19   997.8333          6.733333   47.69167     0.4547792
# 27  2     20   987.0000          8.304167   54.17500     0.5936167
# 28  2     21  1179.4167          5.750000   74.30000     0.6858208
# 29  2     23  1113.0417          4.320833   78.37917     0.6580625
# 30  2     24  1220.0417          5.270833   78.72500     0.7039125
# ⋮   ⋮     ⋮   ⋮                 ⋮           ⋮            ⋮
# 236  7    22  1830.542          32.99583    33.08750     1.4549875
# 237  7    23  1780.458          32.55833    31.85000     1.3979542
# 238  7    30  1744.667          30.02500    37.05417     1.4482458
# 239  8     2  1709.458          30.54583    43.63333     1.7645208
# 240  8     3  1768.333          30.70417    41.35000     1.7445750
# 241  8     4  1698.083          30.57500    42.05833     1.7195250
# 242  8     5  1684.000          26.30417    56.64583     1.8006333
# 243  8     6  1803.917          26.48333    58.03750     1.8899667
# 244  8     9  1700.150          28.19000    51.03000     1.8443350
# 245  8    12  1684.333          30.73750    47.58750     1.9789250
# 246  8    31  1684.958          27.30000    46.18333     1.5827333
# 247  9     1  1683.542          27.07083    42.09167     1.3834833
# 248  9     2  1675.125          28.91667    38.06667     1.3910167
# 249  9    13  1775.917          26.25833    50.00000     1.5848250
# 250  9    14  1716.250          25.19583    55.95417     1.7135500
# 251  9    21  1726.042          24.70417    47.61667     1.4230500
# 252  9    23  1703.417          25.49583    50.78750     1.5961458
# 253 10     1  1769.957          22.07391    60.23478     1.5639739
# 254 10     4  1729.292          22.17500    56.58333     1.4520333
# 255 10     5  1763.333          23.15833    53.55000     1.4494958
# 256 10     6  1736.417          22.77917    55.64583     1.4917375
# 257 10     7  1744.333          23.12917    54.57083     1.4954625
# 258 10     8  1725.708          23.28750    54.93333     1.5154083
# 259 10     9  1724.000          24.88333    54.79167     1.6757875
# 260 10    22  1799.708          22.52917    61.64583     1.6456625
# 261 10    26  1804.917          19.52917    66.21250     1.4673333
# 262 11     1  1706.167          21.22917    70.09167     1.7422583
# 263 11     2  1893.542          20.66667    64.50000     1.5346500
# 264 11     4  1747.583          20.57917    62.00417     1.4643958
# 265 11    23  1731.167          10.73333    75.32500     0.9716542
#    month day daily_avg_PT08_S4 daily_avg_T daily_avg_RH daily_avg_AH
# 1  1      7  1305.6250          8.454167   72.05000     0.7939000
# 2  1     11  1449.5000         12.779167   64.10417     0.9414125
# 3  1     12  1489.1250         11.966667   65.68750     0.9053333
# 4  1     13  1366.6250          9.991667   69.56667     0.8472250
# 5  1     16   948.3333          7.525000   47.77917     0.4804167
# 6  1     27   870.9583          5.270833   39.61250     0.3543292
# 7  2      5   926.8333          5.570833   46.60417     0.4109500
# 8  2      7   873.2500          7.304167   35.40000     0.3529917
# 9  2      8   904.2941          8.764706   36.12353     0.3957765
# 10 2     12  1368.8750          8.316667   59.15000     0.6482583
# 11 2     13  1322.9167         12.854167   60.66667     0.8578875
# 12 2     14  1020.7917         10.479167   40.69583     0.5037500
# 13 2     17  1000.9167          7.491667   44.40000     0.4630750
# 14 2     22  1182.7917          5.412500   75.16250     0.6742750
# 15 2     26   999.0833          6.604167   56.79583     0.5480625
# 16 2     28   750.0833          2.887500   42.66667     0.3272292
# 17 3      3  1162.4167          4.591667   67.45833     0.5775458
# 18 3      8  1048.6250          7.525000   39.19167     0.3688333
# 19 3      9  1236.9167          9.345833   49.39583     0.5727917
# 20 3     13  1372.5833         13.625000   50.72917     0.7697083
# 21 3     28  1314.4167         15.695833   53.24583     0.9249792
# 22 3     31  1345.0417         15.568750   52.55417     0.8968542
# 23 4      4  1421.1026         18.148718   47.32564     0.9196795
# 24 4      7  1470.2500         14.320833   54.71667     0.8671875
# 25 4      8  1598.6087         14.500000   49.39130     0.7362478
# 26 4     11  1265.6667         14.775000   43.76250     0.6673417
# 27 4     12  1217.7917         12.212500   52.97917     0.7398625
# 28 4     13  1542.2083         13.058333   53.05000     0.7821875
# 29 4     18  1559.0417         15.595833   64.13750     1.1218500
# 30 4     23  1801.7083         21.229167   39.15000     0.9110625
# ⋮  ⋮     ⋮   ⋮                 ⋮           ⋮            ⋮
# 63  9     4  1511.7917         30.370833   34.64583     1.3665917
# 64  9    15  1846.6667         22.841667   67.76667     1.8466792
# 65  9    18  1331.8750         24.025000   38.85833     1.1190083
# 66  9    22  1728.0833         24.604167   51.27917     1.4947625
# 67  9    25  1183.8750         17.850000   40.99167     0.8099208
# 68  9    28  1511.8333         19.891667   42.39167     0.9168000
# 69  9    30  1657.9167         21.287500   53.08750     1.3287542
# 70 10    11  1673.2917         19.933333   67.12083     1.5403167
# 71 10    14  1400.2083         17.804167   55.78333     1.1168625
# 72 10    19  1744.2500         18.216667   67.02083     1.3843500
# 73 10    20  1959.3750         21.720833   66.21667     1.6928042
# 74 10    21  1830.7917         23.820833   60.47083     1.7434750
# 75 10    25  1827.0000         18.658333   69.75000     1.4794417
# 76 10    28  1610.0417         18.387500   67.80000     1.4080083
# 77 10    31  1601.0417         20.858333   68.82917     1.6735167
# 78 11     5  1682.0417         19.345833   62.23333     1.3682583
# 79 11     6  1500.7083         18.291667   63.48750     1.3132000
# 80 11     8  1155.8333         11.116667   50.62083     0.6623208
# 81 11    22  1333.0000          6.450000   54.32500     0.5300542
# 82 11    26  1628.9583         12.516667   66.79583     0.9640083
# 83 11    27  1563.1250         13.770833   75.32083     1.1800208
# 84 12     1  1448.5417         10.891667   77.00000     1.0027958
# 85 12     3  1643.4583         15.237500   76.97500     1.3186583
# 86 12     8  1258.7917         14.354167   64.54583     1.0434833
# 87 12    13  1358.6667         10.108333   56.78750     0.6927458
# 88 12    17  1385.5000         12.925000   72.90000     1.0827250
# 89 12    19  1117.5833          5.287500   62.74583     0.5617583
# 90 12    21   976.4583          6.683333   38.65417     0.3802292
# 91 12    23  1221.2083          5.729167   49.10417     0.4474083
# 92 12    31   915.2083          9.350000   39.34167     0.4553208

# %%
num_rows <- nrow(avg_air_quality_train)
num_rows
# Out:
# [1] 265

# %%
ggplot(avg_air_quality_train, aes(x = daily_avg_T, y = daily_avg_PT08_S4)) +
  geom_point() +
  labs(title = "Scatterplot of PT08_S4 vs. Daily Avg T",
       x = "Daily Avg T",
       y = "Daily Avg PT08_S4")


ggplot(avg_air_quality_train, aes(x = daily_avg_RH, y = daily_avg_PT08_S4)) +
  geom_point() +
  labs(title = "Scatterplot of PT08_S4 vs. Daily Avg RH",
       x = "Daily Avg RH",
       y = "Daily Avg PT08_S4")


ggplot(avg_air_quality_train, aes(x = daily_avg_AH, y = daily_avg_PT08_S4)) +
  geom_point() +
  labs(title = "Scatterplot of PT08_S4 vs. Daily Avg AH",
       x = "Daily Avg AH",
       y = "Daily Avg PT08_S4")
# Out:
# plot without title
# plot without title
# plot without title
